# %%
import pandas as pd
import torch
import numpy as np
import torch_model
from sklearn.neighbors import NearestNeighbors
import torchvision.transforms as T
import os
from PIL import Image
import matplotlib.pyplot as plt
import urllib

from PIL import Image
import torch
import torch.nn as nn
from torchvision import transforms

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /var/folders/js/cy4vzdkx28s24qw7922slpkh0000gn/T/ipykernel_18989/2780972185.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pickle

with open("tfidf_vector.pkl", "rb") as f:
    tfidf_vector = pickle.load(f)

# %%
product = pd.read_csv('../dataset/preprocessing_product.csv')
product = product.drop('Unnamed: 0',axis=1)

# 'product_price' 열을 'price'로 이름을 변경
product.rename(columns={'product_price': 'price'}, inplace=True)
# productType 열 추가 및 'mealkit' 값으로 채우기
product['productType'] = 'mealkit'
# discountRate 열 추가 및 5, 10, 20, 30 중 랜덤하게 선택하여 채우기
product['discountRate'] = np.random.choice([5, 10, 20, 30], size=len(product))
product
# Out:
#      product_id                          product_name    price  \
# 0             1            [fresheasy] 나만의 심야식당 3종 세트  26,800원
# 1             2  [fresheasy] 누구나홀딱반한닭 바사칸치킨윙봉 400g 1팩  32,700원
# 2             3  [fresheasy] 누구나홀딱반한닭 바사칸치킨윙봉 400g 3팩  32,700원
# 3             4   [fresheasy] 누구나홀딱반한닭 바사칸치킨윙봉400g 3팩  21,900원
# 4             5  [fresheasy] 누구나홀딱반한닭 쉬림프치킨파히타 2인분 3팩  53,700원
# ..          ...                                   ...      ...
# 304         305      풀무원 전골 밀키트 4종(만두전골/어묵전골) 2개 골라담기  25,130원
# 305         306                      프레시지 사천식 마라탕 2인분  15,900원
# 306         307                   프레시지 우삼겹 마라 떡볶이 2인분  15,900원
# 307         308         핑크퐁 아기상어 클레이 쿠키 만들기 250g x 2개  20,490원
# 308         309         핑크퐁 아기상어 클레이 쿠키 만들기 250g x 4개  41,070원
#
#                                        food_ingredient productType  \
# 0    ['기타가공품', '건마늘분말', '폴리인산나트륨', '복합조미식품', '치자적색소...     mealkit
# 1    ['기타가공품', '복합조미식품', '식물성유지', '닭고기', '혼합제제', '정...     mealkit
# 2    ['기타가공품', '복합조미식품', '식물성유지', '닭고기', '혼합제제', '정...     mealkit
# 3    ['기타가공품', '복합조미식품', '식물성유지', '닭고기', '혼합제제', '정...     mealkit
# 4    ['기타 수산물가공품', '복합조미식품', '빵류', '청피망', '자연치즈', '...     mealkit
# ..                                                 ...         ...
# 304            ['만두', '숙면', '혼합야채', '어묵', '소고기', '소스']     mealkit
# 305  ['소시지', '배추', '팽이버섯', '향미유', '소고기', '소스', '유바'...     mealkit
# 306      ['소시지', '어묵', '향미유', '소고기', '떡류', '소스', '건면']     mealkit
# 307  ['기타가공품', '정제소금', '설탕', '난황액', '밀가루', '코코아분말',...     mealkit
# 308  ['기타가공품', '정제소금', '설탕', '난황액', '밀가루', '코코아분말',...     mealkit
#
#      discountRate
# 0              20
# 1               5
# 2              30
# 3              20
# 4              30
# ..            ...
# 304            20
# 305            10
# 306            20
# 307            10
# 308             5
#
# [309 rows x 6 columns]

# %%
tfidf_matrix = tfidf_vector.fit_transform(product['food_ingredient']).toarray()
tfidf_matrix_feature = tfidf_vector.get_feature_names_out()
tfidf_matrix = pd.DataFrame(tfidf_matrix, columns=tfidf_matrix_feature, index = product.product_name)
# print(tfidf_matrix.shape)
tfidf_matrix.head()

cosine_sim = cosine_similarity(tfidf_matrix)

cosine_sim_df = pd.DataFrame(cosine_sim, index = product.product_name, columns = product.product_name)
# print(cosine_sim_df.shape)
cosine_sim_df.head()

def ingredient_recommendations(target_name, matrix, items, k=10):
    recom_idx = matrix.loc[:, target_name].values.reshape(1, -1).argsort()[:, ::-1].flatten()[1:k+1]
    recom_name = items.iloc[recom_idx, :].product_name.values
    recom_ingredient = items.iloc[recom_idx, :].food_ingredient.values
    target_name_list = np.full(len(range(k)), target_name)
    target_ingredient_list = np.full(len(range(k)), items[items.product_name == target_name].food_ingredient.values)
    d = {
        'target_name':target_name_list,
        'target_ingredient':target_ingredient_list,
        'recom_name' : recom_name,
        'recom_ingredient' : recom_ingredient
    }
    return pd.DataFrame(d)

def ingredient_recommendations_product_name(target_name, matrix, items, k=10):
    recom_idx = matrix.loc[:, target_name].values.reshape(1, -1).argsort()[:, ::-1].flatten()[1:k+1]
    recom_name = items.iloc[recom_idx, :].product_name.values
    return recom_name

def ingredient_recommendations_product_id(target_name, matrix, items, k):
    recom_idx = matrix.loc[:, target_name].values.reshape(1, -1).argsort()[:, ::-1].flatten()[1:k+1]
    recom_id = items.iloc[recom_idx, :].product_id.values
    return recom_id

ingredient_recommendations('[fresheasy] 누구나홀딱반한닭 쉬림프치킨파히타 2인분 3팩', cosine_sim_df, product)
ingredient_recommendations_product_id('[fresheasy] 누구나홀딱반한닭 쉬림프치킨파히타 2인분 3팩', cosine_sim_df, product)
# Out:
# array([ 47,  49,  48,  67,  68, 214, 152, 240, 243, 187])

# %%
def load_image_tensor(image_url, device):
  # 이미지 다운로드
  with urllib.request.urlopen(image_url) as response:
    with open('temp_image.jpg', 'wb') as out_file:
      out_file.write(response.read())

  # 이미지 열기 및 변환
  image = Image.open('temp_image.jpg').convert("RGB")
  image = image.resize((IMG_HEIGHT, IMG_WIDTH))
  image_tensor = transforms.ToTensor()(image)

  # 이미지 텐서를 배치 차원에 맞게 변환
  image_tensor = image_tensor.unsqueeze(0)

  # 임시 이미지 파일 삭제
  os.remove('temp_image.jpg')

  # 이미지 텐서를 GPU 또는 CPU 장치로 전송
  image_tensor = image_tensor.to(device)

  return image_tensor

# %%
def compute_similar_images(image_path, num_images, embedding, device):
    image_tensor = load_image_tensor(image_path, device)
    # image_tensor = image_tensor.to(device)

    with torch.no_grad():
        image_embedding = encoder(image_tensor).cpu().detach().numpy()

    print(image_embedding.shape)

    flattened_embedding = image_embedding.reshape((image_embedding.shape[0], -1))
    print(flattened_embedding.shape)

    knn = NearestNeighbors(n_neighbors=num_images, metric="cosine")
    knn.fit(embedding)

    _, indices = knn.kneighbors(flattened_embedding)
    indices_list = indices.tolist()
    print(indices_list)
    return indices_list

# %%
def plot_similar_images(indices_list):
    if not indices_list:
        print("No similar images found.")
        return

    for sublist in indices_list:
        if not sublist:
            print(f"Skipping empty sublist for image {sublist[0]}.")
            continue

        for index in sublist:
            try:
                img_url = image_urls[index]
                img_name = str(index) + ".jpg"

                # 이미지 다운로드
                with urllib.request.urlopen(img_url) as response:
                    with open(img_name, 'wb') as out_file:
                        out_file.write(response.read())

                # 다운로드한 이미지 열기
                img_path = os.path.join("./", img_name)
                img = Image.open(img_path).convert("RGB")
                plt.imshow(img)
                plt.show()

                # 임시 이미지 파일 삭제
                os.remove(img_name)

            except IndexError:
                print(f"Invalid index: {index}. Skipping...")
    # 추가적인 정리 (이미지 파일 닫기 등)

# %%
def get_product_names(indices_list, products):
    similar_product_names = []

    for sublist in indices_list:
        if not sublist:
            print(f"Skipping empty sublist.")
            continue

        for index in sublist:
            try:
                product_name = products.iloc[index]['product_name']
                similar_product_names.append(product_name)

            except IndexError:
                print(f"Invalid index: {index}. Skipping...")

    return similar_product_names

# %%
def get_product_ids(indices_list, products):
    similar_product_ids = []

    for sublist in indices_list:
        if not sublist:
            print(f"Skipping empty sublist.")
            continue

        for index in sublist:
            try:
                product_id = products.iloc[index]['product_id']
                similar_product_ids.append(product_id)

            except IndexError:
                print(f"Invalid index: {index}. Skipping...")

    return similar_product_ids

# %%
TEST_IMAGE_PATH = "https://image.hmall.com/static/9/9/26/27/2127269978_0.jpg?RS=520x520&AR=0&ao=2"
NUM_IMAGES = 5
ENCODER_MODEL_PATH = "./baseline_encoder.pt"
DECODER_MODEL_PATH = "./baseline_decoder.pt"
EMBEDDING_PATH = "./data_embedding_f.npy"
EMBEDDING_SHAPE = (1, 256, 16, 16)

IMG_HEIGHT = 512 
IMG_WIDTH = 512

# %%
class ConvEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        # self.img_size = img_size
        self.conv1 = nn.Conv2d(3, 16, (3, 3), padding=(1, 1))
        self.relu1 = nn.ReLU(inplace=True)
        self.maxpool1 = nn.MaxPool2d((2, 2))

        self.conv2 = nn.Conv2d(16, 32, (3, 3), padding=(1, 1))
        self.relu2 = nn.ReLU(inplace=True)
        self.maxpool2 = nn.MaxPool2d((2, 2))

        self.conv3 = nn.Conv2d(32, 64, (3, 3), padding=(1, 1))
        self.relu3 = nn.ReLU(inplace=True)
        self.maxpool3 = nn.MaxPool2d((2, 2))

    def forward(self, x):
        # Downscale the image with conv maxpool etc.
        # print(x.shape)
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.maxpool1(x)

        # print(x.shape)

        x = self.conv2(x)
        x = self.relu2(x)
        x = self.maxpool2(x)

        # print(x.shape)

        x = self.conv3(x)
        x = self.relu3(x)
        x = self.maxpool3(x)

        # print(x.shape)
        return x

# %%
import pandas as pd

products = pd.read_csv('../dataset/hmall_food_last.csv')
image_df = products[['image_main']]

products = pd.concat([product, image_df], axis=1)
products
# Out:
#      product_id                          product_name    price  \
# 0             1            [fresheasy] 나만의 심야식당 3종 세트  26,800원
# 1             2  [fresheasy] 누구나홀딱반한닭 바사칸치킨윙봉 400g 1팩  32,700원
# 2             3  [fresheasy] 누구나홀딱반한닭 바사칸치킨윙봉 400g 3팩  32,700원
# 3             4   [fresheasy] 누구나홀딱반한닭 바사칸치킨윙봉400g 3팩  21,900원
# 4             5  [fresheasy] 누구나홀딱반한닭 쉬림프치킨파히타 2인분 3팩  53,700원
# ..          ...                                   ...      ...
# 304         305      풀무원 전골 밀키트 4종(만두전골/어묵전골) 2개 골라담기  25,130원
# 305         306                      프레시지 사천식 마라탕 2인분  15,900원
# 306         307                   프레시지 우삼겹 마라 떡볶이 2인분  15,900원
# 307         308         핑크퐁 아기상어 클레이 쿠키 만들기 250g x 2개  20,490원
# 308         309         핑크퐁 아기상어 클레이 쿠키 만들기 250g x 4개  41,070원
#
#                                        food_ingredient productType  \
# 0    ['기타가공품', '건마늘분말', '폴리인산나트륨', '복합조미식품', '치자적색소...     mealkit
# 1    ['기타가공품', '복합조미식품', '식물성유지', '닭고기', '혼합제제', '정...     mealkit
# 2    ['기타가공품', '복합조미식품', '식물성유지', '닭고기', '혼합제제', '정...     mealkit
# 3    ['기타가공품', '복합조미식품', '식물성유지', '닭고기', '혼합제제', '정...     mealkit
# 4    ['기타 수산물가공품', '복합조미식품', '빵류', '청피망', '자연치즈', '...     mealkit
# ..                                                 ...         ...
# 304            ['만두', '숙면', '혼합야채', '어묵', '소고기', '소스']     mealkit
# 305  ['소시지', '배추', '팽이버섯', '향미유', '소고기', '소스', '유바'...     mealkit
# 306      ['소시지', '어묵', '향미유', '소고기', '떡류', '소스', '건면']     mealkit
# 307  ['기타가공품', '정제소금', '설탕', '난황액', '밀가루', '코코아분말',...     mealkit
# 308  ['기타가공품', '정제소금', '설탕', '난황액', '밀가루', '코코아분말',...     mealkit
#
#      discountRate                                         image_main  \
# 0              20  https://image.hmall.com/static/7/0/89/03/22038...
# 1               5  https://image.hmall.com/static/1/8/54/03/22035...
# 2              30  https://image.hmall.com/static/9/8/39/05/22053...
# 3              20  https://image.hmall.com/static/4/2/57/01/22015...
# 4              30  https://image.hmall.com/static/1/9/39/05/22053...
# ..            ...                                                ...
# 304            20  https://image.hmall.com/static/3/4/60/43/21436...
# 305            10  https://image.hmall.com//m/img/co/noimg-thumb.png
# 306            20  https://image.hmall.com//m/img/co/noimg-thumb.png
# 307            10  https://image.hmall.com/static/4/0/78/52/21527...
# 308             5  https://image.hmall.com/static/4/0/78/52/21527...
#
#                                             image_main
# 0    https://image.hmall.com/static/7/0/89/03/22038...
# 1    https://image.hmall.com/static/1/8/54/03/22035...
# 2    https://image.hmall.com/static/9/8/39/05/22053...
# 3    https://image.hmall.com/static/4/2/57/01/22015...
# 4    https://image.hmall.com/static/1/9/39/05/22053...
# ..                                                 ...
# 304  https://image.hmall.com/static/3/4/60/43/21436...
# 305  https://image.hmall.com//m/img/co/noimg-thumb.png
# 306  https://image.hmall.com//m/img/co/noimg-thumb.png
# 307  https://image.hmall.com/static/4/0/78/52/21527...
# 308  https://image.hmall.com/static/4/0/78/52/21527...
#
# [309 rows x 8 columns]

# %%
image_urls = []

for url in products['image_main']:
    image_urls.append(url)

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
encoder = ConvEncoder()

# Load the state dict of encoder
encoder.load_state_dict(torch.load(ENCODER_MODEL_PATH, map_location=device))
encoder.eval()
encoder.to(device)

# Loads the embedding
embedding = np.load(EMBEDDING_PATH)

indices_list = compute_similar_images(TEST_IMAGE_PATH, NUM_IMAGES, embedding, device)
# plot_similar_images(indices_list)
get_product_ids(indices_list, products)
# Out:
# (1, 64, 64, 64)
# (1, 262144)
# [[274, 277, 268, 264, 280]]
# [275, 278, 269, 265, 281]

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import torch
import torchvision.transforms as transforms
from PIL import Image
import urllib.request
import os
from sklearn.neighbors import NearestNeighbors

def hybrid_recommender(target_name, target_image_path, products, content_matrix, embedding, device, k):
    """하이브리드 추천 시스템 함수"""

    # 콘텐츠 기반 추천 결과
    content_recommendations = ingredient_recommendations_product_name(target_name, content_matrix, products)

    # 이미지 기반 추천 결과
    image_indices = compute_similar_images(target_image_path, k, embedding, device)
    image_recommendations = get_product_names(image_indices, products)

    # 콘텐츠 기반 추천과 이미지 기반 추천의 결과를 결합
    combined_recommendations = pd.DataFrame({'recom_name': content_recommendations, 'recommendation_score': 1})

    # 이미지 기반 추천 결과를 반영하여 추천 점수 업데이트
    for recom_name in image_recommendations:
        if recom_name in combined_recommendations['recom_name'].values:
            combined_recommendations.loc[combined_recommendations['recom_name'] == recom_name, 'recommendation_score'] += 1
        else:
            combined_recommendations = pd.concat([combined_recommendations, pd.DataFrame({'recom_name': [recom_name], 'recommendation_score': [1]})], ignore_index=True)

    # 추천 점수에 따라 정렬
    combined_recommendations = combined_recommendations.sort_values(by='recommendation_score', ascending=False)

    return combined_recommendations

TARGET_PRODUCT = '청정원 호밍스 밀키트 부산식 곱창전골 760g x 2개'
TARGET_IMAGE_PATH = "https://image.hmall.com/static/9/9/26/27/2127269978_0.jpg?RS=520x520&AR=0&ao=2"
NUM_RECOMMENDATIONS = 10
WEIGHT_CONTENT = 0.5
WEIGHT_IMAGE = 0.5


# 예시 사용
hybrid_recommendations = hybrid_recommender(TARGET_PRODUCT, TARGET_IMAGE_PATH, product, cosine_sim_df, embedding, device, 10)
print(hybrid_recommendations)
# Out:
# (1, 64, 64, 64)
# (1, 262144)
# [[274, 277, 268, 264, 280, 271, 266, 282, 265, 272]]
#                                          recom_name  recommendation_score
# 0                         청정원 호밍스 밀키트 부산식 곱창전골 760g                     2
# 1   청정원 호밍스 밀키트 부산식 곱창전골 760g x 2개 + (증정)돼지양념구이210g                     2
# 2                            청정원 호밍스 밀키트 낙곱새전골 800g                     2
# 8                        청정원 호밍스 밀키트 춘천식 치즈닭갈비 220g                     2
# 3                       청정원 호밍스 밀키트 낙곱새전골 800g x 2개                     1
# 4                           청정원 호밍스 밀키트 춘천 닭갈비 800g                     1
# 5                     [족발야시장] 족발야시장 직화 양념곱창 250g 3팩                     1
# 6                    [족발야시장] 족발야시장 직화 양념곱창 250g 10팩                     1
# 7                     [족발야시장] 족발야시장 직화 양념곱창 250g 6팩                     1
# 9                     청정원 호밍스 밀키트 햄/고기 듬뿍 부대찌개 600g                     1
# 10                       청정원 호밍스 밀키트 언양식 바싹불고기 270g                     1
# 11                      청정원 호밍스 밀키트 마포식 돼지양념구이 210g                     1
# 12                     청정원 호밍스 밀키트 궁중식 간장양념 찜닭 670g                     1
# 13      청정원 호밍스 밀키트 바싹불고기 270g x 3개 +(증정)돼지양념구이210g                     1
# 14                 청정원 호밍스 밀키트4종 골라담기 +(증)치즈닭갈비220g                     1
# 15                       청정원 호밍스 밀키트 기사식당 돼지불백 400g                     1

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import torch
import torchvision.transforms as transforms
from PIL import Image
import urllib.request
import os
from sklearn.neighbors import NearestNeighbors

def hybrid_recommender(target_name, target_image_path, products, content_matrix, embedding, device, k):
    """하이브리드 추천 시스템 함수"""

    # 콘텐츠 기반 추천 결과
    content_recommendations = ingredient_recommendations_product_id(target_name, content_matrix, products, k)

    # 이미지 기반 추천 결과
    image_indices = compute_similar_images(target_image_path, k, embedding, device)
    image_recommendations = get_product_ids(image_indices, products)

    # 콘텐츠 기반 추천과 이미지 기반 추천의 결과를 결합
    combined_recommendations = pd.DataFrame({'recom_id': content_recommendations, 'recommendation_score': 1})

    # 이미지 기반 추천 결과를 반영하여 추천 점수 업데이트
    for recom_id in image_recommendations:
        if recom_id in combined_recommendations['recom_id'].values:
            combined_recommendations.loc[combined_recommendations['recom_id'] == recom_id, 'recommendation_score'] += 1
        else:
            combined_recommendations = pd.concat([combined_recommendations, pd.DataFrame({'recom_id': [recom_id], 'recommendation_score': [1]})], ignore_index=True)

    # 추천 점수에 따라 정렬
    combined_recommendations = combined_recommendations.sort_values(by='recommendation_score', ascending=False)
    
    # recom_id에 해당하는 product 데이터를 데이터프레임 형태로 반환
    recommended_products = pd.DataFrame()
    for recom_id in combined_recommendations['recom_id']:
        recommended_products = pd.concat([recommended_products, products[products['product_id'] == recom_id]], ignore_index=True)

    return recommended_products


TARGET_PRODUCT = '청정원 호밍스 밀키트 부산식 곱창전골 760g x 2개'
TARGET_IMAGE_PATH = "https://image.hmall.com/static/9/9/26/27/2127269978_0.jpg?RS=520x520&AR=0&ao=2"
NUM_RECOMMENDATIONS = 10
WEIGHT_CONTENT = 0.5
WEIGHT_IMAGE = 0.5


# 예시 사용
hybrid_recommendations = hybrid_recommender(TARGET_PRODUCT, TARGET_IMAGE_PATH, product, cosine_sim_df, embedding, device, NUM_RECOMMENDATIONS)
hybrid_recommendations
# Out:
# (1, 64, 64, 64)
# (1, 262144)
# [[274, 277, 268, 264, 280, 271, 266, 282, 265, 272]]
#     product_id                                     product_name    price  \
# 0          273                        청정원 호밍스 밀키트 부산식 곱창전골 760g  12,130원
# 1          275  청정원 호밍스 밀키트 부산식 곱창전골 760g x 2개 + (증정)돼지양념구이210g  21,990원
# 2          267                           청정원 호밍스 밀키트 낙곱새전골 800g  16,900원
# 3          281                       청정원 호밍스 밀키트 춘천식 치즈닭갈비 220g   6,780원
# 4          268                      청정원 호밍스 밀키트 낙곱새전골 800g x 2개  28,130원
# 5          280                          청정원 호밍스 밀키트 춘천 닭갈비 800g  13,900원
# 6           86                    [족발야시장] 족발야시장 직화 양념곱창 250g 3팩  24,900원
# 7           85                   [족발야시장] 족발야시장 직화 양념곱창 250g 10팩  67,900원
# 8           87                    [족발야시장] 족발야시장 직화 양념곱창 250g 6팩  46,900원
# 9          282                    청정원 호밍스 밀키트 햄/고기 듬뿍 부대찌개 600g  15,280원
# 10         278                       청정원 호밍스 밀키트 언양식 바싹불고기 270g   8,720원
# 11         269                      청정원 호밍스 밀키트 마포식 돼지양념구이 210g   6,780원
# 12         265                     청정원 호밍스 밀키트 궁중식 간장양념 찜닭 670g  15,280원
# 13         272      청정원 호밍스 밀키트 바싹불고기 270g x 3개 +(증정)돼지양념구이210g  24,390원
# 14         283                 청정원 호밍스 밀키트4종 골라담기 +(증)치즈닭갈비220g  25,460원
# 15         266                       청정원 호밍스 밀키트 기사식당 돼지불백 400g   9,980원
#
#                                       food_ingredient productType  \
# 0   ['복합조미식품', '정제소금', '들깻잎', '식육추출가공품', '알긴산프로필렌글...     mealkit
# 1   ['복합조미식품', '정제소금', '들깻잎', '식육추출가공품', '알긴산프로필렌글...     mealkit
# 2        ['정제소금', '밀가루', '정제수', '알긴산프로필렌글리콜', '변성전분']     mealkit
# 3   ['복합조미식품', '들깻잎', '닭고기', '고춧가루', '설탕', '식품첨가물'...     mealkit
# 4        ['정제소금', '밀가루', '정제수', '알긴산프로필렌글리콜', '변성전분']     mealkit
# 5   ['복합조미식품', '정제소금', '들깻잎', '향미유', '알긴산프로필렌글리콜',...     mealkit
# 6           ['복합조미식품', '설탕', '천연향신료', '돼지곱창', '고춧가루']     mealkit
# 7           ['복합조미식품', '설탕', '천연향신료', '돼지곱창', '고춧가루']     mealkit
# 8           ['복합조미식품', '설탕', '천연향신료', '돼지곱창', '고춧가루']     mealkit
# 9   ['소시지', '복합조미식품', '정제소금', '식육추출가공품', '알긴산프로필렌글...     mealkit
# 10  ['새송이버섯', '설탕', '식품첨가물', '기타설탕', '소고기', '천연향신료...     mealkit
# 11  ['복합조미식품', '고춧가루', '설탕', '소스', '정제수', '콩기름(대두유...     mealkit
# 12  ['복합조미식품', '정제소금', '설탕', '카라멜색소', '천연향신료', '구아...     mealkit
# 13  ['복합조미식품', '기타설탕', '물엿', '고춧가루', '설탕', '식품첨가물'...     mealkit
# 14  ['복합조미식품', '숙면', '정제소금', '들깻잎', '기타설탕', '카라멜색소...     mealkit
# 15  ['복합조미식품', '카라멜색소', '다진생강', '고춧가루', '양파분말', '설...     mealkit
#
#     discountRate                                         image_main
# 0             20  https://image.hmall.com/static/0/9/26/27/21272...
# 1             30  https://image.hmall.com/static/4/4/73/50/21507...
# 2             20  https://image.hmall.com/static/8/1/55/33/21335...
# 3             30  https://image.hmall.com/static/0/9/26/27/21272...
# 4              5  https://image.hmall.com/static/8/1/55/33/21335...
# 5             20  https://image.hmall.com/static/1/5/34/41/21413...
# 6             10  https://image.hmall.com/static/3/7/98/49/21499...
# 7             20  https://image.hmall.com/static/7/7/98/49/21499...
# 8             20  https://image.hmall.com/static/4/7/98/49/21499...
# 9              5  https://image.hmall.com/static/1/3/19/47/21471...
# 10            30  https://image.hmall.com/static/1/9/26/27/21272...
# 11            30  https://image.hmall.com/static/0/9/26/27/21272...
# 12            30  https://image.hmall.com/static/1/3/19/47/21471...
# 13             5  https://image.hmall.com/static/3/4/73/50/21507...
# 14            20  https://image.hmall.com/static/6/5/90/50/21509...
# 15             5  https://image.hmall.com/static/1/5/34/41/21413...

# %%
# product_id, product_name, price, food_ingredient, productType, discountRate, image_main

def hybrid_recommender(target_name, target_image_path, products, content_matrix, embedding, device, k):
    """하이브리드 추천 시스템 함수"""

    # 콘텐츠 기반 추천 결과
    content_recommendations = ingredient_recommendations_product_id(target_name, content_matrix, products, k)

    # 이미지 기반 추천 결과
    image_indices = compute_similar_images(target_image_path, k, embedding, device)
    image_recommendations = get_product_ids(image_indices, products)

    # 콘텐츠 기반 추천과 이미지 기반 추천의 결과를 결합
    combined_recommendations = pd.DataFrame({'recom_id': content_recommendations, 'recommendation_score': 1})

    # 이미지 기반 추천 결과를 반영하여 추천 점수 업데이트
    for recom_id in image_recommendations:
        if recom_id in combined_recommendations['recom_id'].values:
            combined_recommendations.loc[combined_recommendations['recom_id'] == recom_id, 'recommendation_score'] += 1
        else:
            combined_recommendations = pd.concat([combined_recommendations, pd.DataFrame({'recom_id': [recom_id], 'recommendation_score': [1]})], ignore_index=True)

    # 추천 점수에 따라 정렬
    combined_recommendations = combined_recommendations.sort_values(by='recommendation_score', ascending=False)

    # recom_id에 해당하는 product 데이터를 데이터프레임 형태로 반환
    recommended_products = pd.DataFrame()
    for recom_id in combined_recommendations['recom_id']:
        recommended_products = pd.concat([recommended_products, products[products['product_id'] == recom_id]], ignore_index=True)

    # 데이터프레임을 JSON 형태로 변환
    result = []
    for index, row in recommended_products.iterrows():
        result.append({
            "product_id": str(row['product_id']),
            "product_name": str(row['product_name']),
            "price": str(row['price']),
            "mainImgUrl": str(row['image_main']),
            "productType" : str(row['productType']), 
            "discountRate" : int(row['discountRate'])
        })    
    return result



TARGET_PRODUCT = '청정원 호밍스 밀키트 부산식 곱창전골 760g x 2개'
TARGET_IMAGE_PATH = "https://image.hmall.com/static/9/9/26/27/2127269978_0.jpg?RS=520x520&AR=0&ao=2"
NUM_RECOMMENDATIONS = 10
WEIGHT_CONTENT = 0.5
WEIGHT_IMAGE = 0.5


# 예시 사용
hybrid_recommendations = hybrid_recommender(TARGET_PRODUCT, TARGET_IMAGE_PATH, product, cosine_sim_df, embedding, device, NUM_RECOMMENDATIONS)
hybrid_recommendations
# Out:
# (1, 64, 64, 64)
# (1, 262144)
# [[274, 277, 268, 264, 280, 271, 266, 282, 265, 272]]
# [{'product_id': '273',
#   'product_name': '청정원 호밍스 밀키트 부산식 곱창전골 760g',
#   'price': '12,130원',
#   'mainImgUrl': 'https://image.hmall.com/static/0/9/26/27/2127269096_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 20},
#  {'product_id': '275',
#   'product_name': '청정원 호밍스 밀키트 부산식 곱창전골 760g x 2개 + (증정)돼지양념구이210g',
#   'price': '21,990원',
#   'mainImgUrl': 'https://image.hmall.com/static/4/4/73/50/2150734481_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 30},
#  {'product_id': '267',
#   'product_name': '청정원 호밍스 밀키트 낙곱새전골 800g',
#   'price': '16,900원',
#   'mainImgUrl': 'https://image.hmall.com/static/8/1/55/33/2133551852_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 20},
#  {'product_id': '281',
#   'product_name': '청정원 호밍스 밀키트 춘천식 치즈닭갈비 220g',
#   'price': '6,780원',
#   'mainImgUrl': 'https://image.hmall.com/static/0/9/26/27/2127269092_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 30},
#  {'product_id': '268',
#   'product_name': '청정원 호밍스 밀키트 낙곱새전골 800g x 2개',
#   'price': '28,130원',
#   'mainImgUrl': 'https://image.hmall.com/static/8/1/55/33/2133551847_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 5},
#  {'product_id': '280',
#   'product_name': '청정원 호밍스 밀키트 춘천 닭갈비 800g',
#   'price': '13,900원',
#   'mainImgUrl': 'https://image.hmall.com/static/1/5/34/41/2141345109_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 20},
#  {'product_id': '86',
#   'product_name': '[족발야시장] 족발야시장 직화 양념곱창 250g 3팩',
#   'price': '24,900원',
#   'mainImgUrl': 'https://image.hmall.com/static/3/7/98/49/2149987337_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 10},
#  {'product_id': '85',
#   'product_name': '[족발야시장] 족발야시장 직화 양념곱창 250g 10팩',
#   'price': '67,900원',
#   'mainImgUrl': 'https://image.hmall.com/static/7/7/98/49/2149987744_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 20},
#  {'product_id': '87',
#   'product_name': '[족발야시장] 족발야시장 직화 양념곱창 250g 6팩',
#   'price': '46,900원',
#   'mainImgUrl': 'https://image.hmall.com/static/4/7/98/49/2149987488_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 20},
#  {'product_id': '282',
#   'product_name': '청정원 호밍스 밀키트 햄/고기 듬뿍 부대찌개 600g',
#   'price': '15,280원',
#   'mainImgUrl': 'https://image.hmall.com/static/1/3/19/47/2147193185_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 5},
#  {'product_id': '278',
#   'product_name': '청정원 호밍스 밀키트 언양식 바싹불고기 270g',
#   'price': '8,720원',
#   'mainImgUrl': 'https://image.hmall.com/static/1/9/26/27/2127269101_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 30},
#  {'product_id': '269',
#   'product_name': '청정원 호밍스 밀키트 마포식 돼지양념구이 210g',
#   'price': '6,780원',
#   'mainImgUrl': 'https://image.hmall.com/static/0/9/26/27/2127269088_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 30},
#  {'product_id': '265',
#   'product_name': '청정원 호밍스 밀키트 궁중식 간장양념 찜닭 670g',
#   'price': '15,280원',
#   'mainImgUrl': 'https://image.hmall.com/static/1/3/19/47/2147193109_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 30},
#  {'product_id': '272',
#   'product_name': '청정원 호밍스 밀키트 바싹불고기 270g x 3개 +(증정)돼지양념구이210g',
#   'price': '24,390원',
#   'mainImgUrl': 'https://image.hmall.com/static/3/4/73/50/2150734356_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 5},
#  {'product_id': '283',
#   'product_name': '청정원 호밍스 밀키트4종 골라담기 +(증)치즈닭갈비220g',
#   'price': '25,460원',
#   'mainImgUrl': 'https://image.hmall.com/static/6/5/90/50/2150905618_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 20},
#  {'product_id': '266',
#   'product_name': '청정원 호밍스 밀키트 기사식당 돼지불백 400g',
#   'price': '9,980원',
#   'mainImgUrl': 'https://image.hmall.com/static/1/5/34/41/2141345112_0.jpg?RS=520x520&AR=0&ao=2',
#   'productType': 'mealkit',
#   'discountRate': 5}]
